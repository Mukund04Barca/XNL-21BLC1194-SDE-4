# %%
from faker import Faker
import random
import mysql.connector

# Initialize Faker
fake = Faker()

# Database connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="0101",
    database="fintech_platform"
)
cursor = conn.cursor()

# Disable autocommit for better performance
conn.autocommit = False

# Generate and insert Users in batches
batch_size = 5000  # ✅ Reduce batch size to optimize performance
user_data = []

for i in range(1, 1000001):  # ✅ Use range(1, 1000001) for tracking
    name = fake.name()
    email = fake.unique.email()  # ✅ Ensures unique emails
    password_hash = fake.sha256()[:64]  # ✅ Trim to fit VARCHAR(64)
    role = random.choice(['customer', 'vendor', 'admin'])
    user_data.append((name, email, password_hash, role))

    # ✅ Insert in smaller batches to prevent memory overload
    if i % batch_size == 0:
        try:
            cursor.executemany(
                "INSERT INTO Users (name, email, password_hash, role) VALUES (%s, %s, %s, %s)",
                user_data
            )
            conn.commit()
            print(f"Inserted {i} users ✅")  # ✅ Progress tracking
        except mysql.connector.Error as err:
            print(f"Error: {err}")
            conn.rollback()  # ✅ Rollback on failure
        user_data = []  # ✅ Clear memory

# ✅ Insert remaining users
if user_data:
    try:
        cursor.executemany(
            "INSERT INTO Users (name, email, password_hash, role) VALUES (%s, %s, %s, %s)",
            user_data
        )
        conn.commit()
        print("Final batch inserted ✅")
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        conn.rollback()

# Close connection
cursor.close()
conn.close()

print("Data Insertion Completed Successfully 🚀")
# Out:
# Inserted 5000 users ✅
# Inserted 10000 users ✅
# Inserted 15000 users ✅
# Inserted 20000 users ✅
# Inserted 25000 users ✅
# Inserted 30000 users ✅
# Inserted 35000 users ✅
# Inserted 40000 users ✅
# Inserted 45000 users ✅
# Inserted 50000 users ✅
# Inserted 55000 users ✅
# Inserted 60000 users ✅
# Inserted 65000 users ✅
# Inserted 70000 users ✅
# Inserted 75000 users ✅
# Inserted 80000 users ✅
# Inserted 85000 users ✅
# Inserted 90000 users ✅
# Inserted 95000 users ✅
# Inserted 100000 users ✅
# Inserted 105000 users ✅
# Inserted 110000 users ✅
# Inserted 115000 users ✅
# Inserted 120000 users ✅
# Inserted 125000 users ✅
# Inserted 130000 users ✅
# Inserted 135000 users ✅
# Inserted 140000 users ✅
# Inserted 145000 users ✅
# Inserted 150000 users ✅
# Inserted 155000 users ✅
# Inserted 160000 users ✅
# Inserted 165000 users ✅
# Inserted 170000 users ✅
# Inserted 175000 users ✅
# Inserted 180000 users ✅
# Inserted 185000 users ✅
# Inserted 190000 users ✅
# Inserted 195000 users ✅
# Inserted 200000 users ✅
# Inserted 205000 users ✅
# Inserted 210000 users ✅
# Inserted 215000 users ✅
# Inserted 220000 users ✅
# Inserted 225000 users ✅
# Inserted 230000 users ✅
# Inserted 235000 users ✅
# Inserted 240000 users ✅
# Inserted 245000 users ✅
# Inserted 250000 users ✅
# Inserted 255000 users ✅
# Inserted 260000 users ✅
# Inserted 265000 users ✅
# Inserted 270000 users ✅
# Inserted 275000 users ✅
# Inserted 280000 users ✅
# Inserted 285000 users ✅
# Inserted 290000 users ✅
# Inserted 295000 users ✅
# Inserted 300000 users ✅
# Inserted 305000 users ✅
# Inserted 310000 users ✅
# Inserted 315000 users ✅
# Inserted 320000 users ✅
# Inserted 325000 users ✅
# Inserted 330000 users ✅
# Inserted 335000 users ✅
# Inserted 340000 users ✅
# Inserted 345000 users ✅
# Inserted 350000 users ✅
# Inserted 355000 users ✅
# Inserted 360000 users ✅
# Inserted 365000 users ✅
# Inserted 370000 users ✅
# Inserted 375000 users ✅
# Inserted 380000 users ✅
# Inserted 385000 users ✅
# Inserted 390000 users ✅
# Inserted 395000 users ✅
# Inserted 400000 users ✅
# Inserted 405000 users ✅
# Inserted 410000 users ✅
# Inserted 415000 users ✅
# Inserted 420000 users ✅
# Inserted 425000 users ✅
# Inserted 430000 users ✅
# Inserted 435000 users ✅
# Inserted 440000 users ✅
# Inserted 445000 users ✅
# Inserted 450000 users ✅
# Inserted 455000 users ✅
# Inserted 460000 users ✅
# Inserted 465000 users ✅
# Inserted 470000 users ✅
# Inserted 475000 users ✅
# Inserted 480000 users ✅
# Inserted 485000 users ✅
# Inserted 490000 users ✅
# Inserted 495000 users ✅
# Inserted 500000 users ✅
# Inserted 505000 users ✅
# Inserted 510000 users ✅
# Inserted 515000 users ✅
# Inserted 520000 users ✅
# Inserted 525000 users ✅
# Inserted 530000 users ✅
# Inserted 535000 users ✅
# Inserted 540000 users ✅
# Inserted 545000 users ✅
# Inserted 550000 users ✅
# Inserted 555000 users ✅
# Inserted 560000 users ✅
# Inserted 565000 users ✅
# Inserted 570000 users ✅
# Inserted 575000 users ✅
# Inserted 580000 users ✅
# Inserted 585000 users ✅
# Inserted 590000 users ✅
# Inserted 595000 users ✅
# Inserted 600000 users ✅
# Inserted 605000 users ✅
# Inserted 610000 users ✅
# Inserted 615000 users ✅
# Inserted 620000 users ✅
# Inserted 625000 users ✅
# Inserted 630000 users ✅
# Inserted 635000 users ✅
# Inserted 640000 users ✅
# Inserted 645000 users ✅
# Inserted 650000 users ✅
# Inserted 655000 users ✅
# Inserted 660000 users ✅
# Inserted 665000 users ✅
# Inserted 670000 users ✅
# Inserted 675000 users ✅
# Inserted 680000 users ✅
# Inserted 685000 users ✅
# Inserted 690000 users ✅
# Inserted 695000 users ✅
# Inserted 700000 users ✅
# Inserted 705000 users ✅
# Inserted 710000 users ✅
# Inserted 715000 users ✅
# Inserted 720000 users ✅
# Inserted 725000 users ✅
# Inserted 730000 users ✅
# Inserted 735000 users ✅
# Inserted 740000 users ✅
# Inserted 745000 users ✅
# Inserted 750000 users ✅
# Inserted 755000 users ✅
# Inserted 760000 users ✅
# Inserted 765000 users ✅
# Inserted 770000 users ✅
# Inserted 775000 users ✅
# Inserted 780000 users ✅
# Inserted 785000 users ✅
# Inserted 790000 users ✅
# Inserted 795000 users ✅
# Inserted 800000 users ✅
# Inserted 805000 users ✅
# Inserted 810000 users ✅
# Inserted 815000 users ✅
# Inserted 820000 users ✅
# Inserted 825000 users ✅
# Inserted 830000 users ✅
# Inserted 835000 users ✅
# Inserted 840000 users ✅
# Inserted 845000 users ✅
# Inserted 850000 users ✅
# Inserted 855000 users ✅
# Inserted 860000 users ✅
# Inserted 865000 users ✅
# Inserted 870000 users ✅
# Inserted 875000 users ✅
# Inserted 880000 users ✅
# Inserted 885000 users ✅
# Inserted 890000 users ✅
# Inserted 895000 users ✅
# Inserted 900000 users ✅
# Inserted 905000 users ✅
# Inserted 910000 users ✅
# Inserted 915000 users ✅
# Inserted 920000 users ✅
# Inserted 925000 users ✅
# Inserted 930000 users ✅
# Inserted 935000 users ✅
# Inserted 940000 users ✅
# Inserted 945000 users ✅
# Inserted 950000 users ✅
# Inserted 955000 users ✅
# Inserted 960000 users ✅
# Inserted 965000 users ✅
# Inserted 970000 users ✅
# Inserted 975000 users ✅
# Inserted 980000 users ✅
# Inserted 985000 users ✅
# Inserted 990000 users ✅
# Inserted 995000 users ✅
# Inserted 1000000 users ✅
# Data Insertion Completed Successfully 🚀
